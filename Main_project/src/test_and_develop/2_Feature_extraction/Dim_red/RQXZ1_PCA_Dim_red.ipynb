# %% [markdown]
# # RQXZ1: DIM reduction
# gold

# %%
import pandas as pd

df_feat_ictalVspreictal_1min = pd.read_pickle("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/RQXZ1/Feature_ext/Part2_features/RQXZ1_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260510_v01_FEAT-TIME-FREQ_20260510_v01/RQXZ1_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260510_v01_FEAT-TIME-FREQ_20260510_v01_df_features_ictalVspreictal.pkl")

print(df_feat_ictalVspreictal_1min.head())
# Out:
#                     file_name  window_id  start_sample  end_sample  \
# 0  RQXZ1_348_preproc_full.npz        384        794880      796950
# 1  RQXZ1_348_preproc_full.npz        385        796950      799020
# 2  RQXZ1_348_preproc_full.npz        386        799020      801090
# 3  RQXZ1_348_preproc_full.npz        387        801090      803160
# 4  RQXZ1_348_preproc_full.npz        388        803160      805230
#
#            fs  n_channels  window_sec                seizure_onsets  \
# 0  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 1  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 2  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 3  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 4  207.031055           2          10  [2021-01-25 22:09:33.000000]
#
#               window_start_time               window_end_time  ...  \
# 0 2021-01-25 22:03:26.423999874 2021-01-25 22:03:36.422499874  ...
# 1 2021-01-25 22:03:36.422499874 2021-01-25 22:03:46.420999874  ...
# 2 2021-01-25 22:03:46.420999874 2021-01-25 22:03:56.419499873  ...
# 3 2021-01-25 22:03:56.419499873 2021-01-25 22:04:06.417999873  ...
# 4 2021-01-25 22:04:06.417999873 2021-01-25 22:04:16.416499873  ...
#
#    alpha_power_EEG_SQ_D_SQ_C beta_power_EEG_SQ_D_SQ_C  \
# 0                   0.009333                 0.017330
# 1                   0.012844                 0.018002
# 2                   0.020102                 0.022407
# 3                   0.008454                 0.017888
# 4                   0.011653                 0.021627
#
#   gamma_power_EEG_SQ_D_SQ_C  peak_frequency_EEG_SQ_D_SQ_C  \
# 0                  0.005018                      1.000150
# 1                  0.005159                      0.500075
# 2                  0.006948                      1.000150
# 3                  0.005391                      1.000150
# 4                  0.005459                      0.500075
#
#    delta_power_EEG_SQ_P_SQ_C  theta_power_EEG_SQ_P_SQ_C  \
# 0                   0.020635                   0.021386
# 1                   0.020700                   0.017561
# 2                   0.038508                   0.028938
# 3                   0.014299                   0.011431
# 4                   0.020368                   0.011998
#
#    alpha_power_EEG_SQ_P_SQ_C  beta_power_EEG_SQ_P_SQ_C  \
# 0                   0.017917                  0.057057
# 1                   0.012600                  0.065202
# 2                   0.022923                  0.061004
# 3                   0.014290                  0.051468
# 4                   0.016521                  0.055766
#
#    gamma_power_EEG_SQ_P_SQ_C  peak_frequency_EEG_SQ_P_SQ_C
# 0                   0.017111                      1.500225
# 1                   0.020605                      1.000150
# 2                   0.025144                      1.000150
# 3                   0.018759                      1.500225
# 4                   0.016282                      1.000150
#
# [5 rows x 41 columns]

# %%
for col in df_feat_ictalVspreictal_1min.columns:
    print(col)
# Out:
# file_name
# window_id
# start_sample
# end_sample
# fs
# n_channels
# window_sec
# seizure_onsets
# window_start_time
# window_end_time
# class_label
# label_name
# excluded_reason
# mean_EEG_SQ_D_SQ_C
# std_EEG_SQ_D_SQ_C
# var_EEG_SQ_D_SQ_C
# rms_EEG_SQ_D_SQ_C
# ptp_EEG_SQ_D_SQ_C
# line_length_EEG_SQ_D_SQ_C
# skew_EEG_SQ_D_SQ_C
# kurtosis_EEG_SQ_D_SQ_C
# mean_EEG_SQ_P_SQ_C
# std_EEG_SQ_P_SQ_C
# var_EEG_SQ_P_SQ_C
# rms_EEG_SQ_P_SQ_C
# ptp_EEG_SQ_P_SQ_C
# line_length_EEG_SQ_P_SQ_C
# skew_EEG_SQ_P_SQ_C
# kurtosis_EEG_SQ_P_SQ_C
# delta_power_EEG_SQ_D_SQ_C
# theta_power_EEG_SQ_D_SQ_C
# alpha_power_EEG_SQ_D_SQ_C
# beta_power_EEG_SQ_D_SQ_C
# gamma_power_EEG_SQ_D_SQ_C
# peak_frequency_EEG_SQ_D_SQ_C
# delta_power_EEG_SQ_P_SQ_C
# theta_power_EEG_SQ_P_SQ_C
# alpha_power_EEG_SQ_P_SQ_C
# beta_power_EEG_SQ_P_SQ_C
# gamma_power_EEG_SQ_P_SQ_C
# peak_frequency_EEG_SQ_P_SQ_C

# %% [markdown]
# ## 1. separate metadata from features

# %%
# Columns that are NOT EEG features
metadata_cols = [
    "file_name",
    "window_id",
    "start_sample",
    "end_sample",
    "fs",
    "n_channels",
    "window_sec",
    "seizure_onsets",
    "window_start_time",
    "window_end_time",
    "class_label",
    "label_name",
    "excluded_reason"
]

# Feature columns = everything except metadata
feature_cols = [col for col in df_feat_ictalVspreictal_1min.columns if col not in metadata_cols]

print("Number of feature columns:", len(feature_cols))
print(feature_cols)
# Out:
# Number of feature columns: 28
# ['mean_EEG_SQ_D_SQ_C', 'std_EEG_SQ_D_SQ_C', 'var_EEG_SQ_D_SQ_C', 'rms_EEG_SQ_D_SQ_C', 'ptp_EEG_SQ_D_SQ_C', 'line_length_EEG_SQ_D_SQ_C', 'skew_EEG_SQ_D_SQ_C', 'kurtosis_EEG_SQ_D_SQ_C', 'mean_EEG_SQ_P_SQ_C', 'std_EEG_SQ_P_SQ_C', 'var_EEG_SQ_P_SQ_C', 'rms_EEG_SQ_P_SQ_C', 'ptp_EEG_SQ_P_SQ_C', 'line_length_EEG_SQ_P_SQ_C', 'skew_EEG_SQ_P_SQ_C', 'kurtosis_EEG_SQ_P_SQ_C', 'delta_power_EEG_SQ_D_SQ_C', 'theta_power_EEG_SQ_D_SQ_C', 'alpha_power_EEG_SQ_D_SQ_C', 'beta_power_EEG_SQ_D_SQ_C', 'gamma_power_EEG_SQ_D_SQ_C', 'peak_frequency_EEG_SQ_D_SQ_C', 'delta_power_EEG_SQ_P_SQ_C', 'theta_power_EEG_SQ_P_SQ_C', 'alpha_power_EEG_SQ_P_SQ_C', 'beta_power_EEG_SQ_P_SQ_C', 'gamma_power_EEG_SQ_P_SQ_C', 'peak_frequency_EEG_SQ_P_SQ_C']

# %% [markdown]
# ## 2. Build matrix

# %%
X = df_feat_ictalVspreictal_1min[feature_cols].copy()
y = df_feat_ictalVspreictal_1min["class_label"].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (2443, 28)
# y shape: (2443,)

# %% [markdown]
# ## 3. check for NaNs or inf

# %%
import numpy as np

print("NaNs per column:")
print(X.isna().sum())

print("Any infinite values?")
print(np.isinf(X).sum().sum())
# Out:
# NaNs per column:
# mean_EEG_SQ_D_SQ_C              0
# std_EEG_SQ_D_SQ_C               0
# var_EEG_SQ_D_SQ_C               0
# rms_EEG_SQ_D_SQ_C               0
# ptp_EEG_SQ_D_SQ_C               0
# line_length_EEG_SQ_D_SQ_C       0
# skew_EEG_SQ_D_SQ_C              0
# kurtosis_EEG_SQ_D_SQ_C          0
# mean_EEG_SQ_P_SQ_C              0
# std_EEG_SQ_P_SQ_C               0
# var_EEG_SQ_P_SQ_C               0
# rms_EEG_SQ_P_SQ_C               0
# ptp_EEG_SQ_P_SQ_C               0
# line_length_EEG_SQ_P_SQ_C       0
# skew_EEG_SQ_P_SQ_C              0
# kurtosis_EEG_SQ_P_SQ_C          0
# delta_power_EEG_SQ_D_SQ_C       0
# theta_power_EEG_SQ_D_SQ_C       0
# alpha_power_EEG_SQ_D_SQ_C       0
# beta_power_EEG_SQ_D_SQ_C        0
# gamma_power_EEG_SQ_D_SQ_C       0
# peak_frequency_EEG_SQ_D_SQ_C    0
# delta_power_EEG_SQ_P_SQ_C       0
# theta_power_EEG_SQ_P_SQ_C       0
# alpha_power_EEG_SQ_P_SQ_C       0
# beta_power_EEG_SQ_P_SQ_C        0
# gamma_power_EEG_SQ_P_SQ_C       0
# peak_frequency_EEG_SQ_P_SQ_C    0
# dtype: int64
# Any infinite values?
# 0

# %% [markdown]
# ## 4. Scale features before PCA
# PCA needs features to be in comparable scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("X_scaled shape:", X_scaled.shape)
# Out:
# X_scaled shape: (2443, 28)

# %% [markdown]
# ## 5. Apply PCA. start with only 5 components first

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA with all possible components
pca_full = PCA()
X_pca_full = pca_full.fit_transform(X_scaled)

# Explained variance
explained_var = pca_full.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

# Print explained variance per PC
for i, (var, cum_var) in enumerate(zip(explained_var, cumulative_var), start=1):
    print(f"PC{i}: {var*100:.2f}% | cumulative: {cum_var*100:.2f}%")
# Out:
# PC1: 55.91% | cumulative: 55.91%
# PC2: 9.80% | cumulative: 65.70%
# PC3: 6.49% | cumulative: 72.20%
# PC4: 4.76% | cumulative: 76.96%
# PC5: 4.48% | cumulative: 81.44%
# PC6: 3.49% | cumulative: 84.92%
# PC7: 2.80% | cumulative: 87.72%
# PC8: 2.57% | cumulative: 90.30%
# PC9: 2.34% | cumulative: 92.64%
# PC10: 1.81% | cumulative: 94.45%
# PC11: 1.50% | cumulative: 95.95%
# PC12: 1.17% | cumulative: 97.12%
# PC13: 0.66% | cumulative: 97.78%
# PC14: 0.52% | cumulative: 98.30%
# PC15: 0.41% | cumulative: 98.71%
# PC16: 0.36% | cumulative: 99.07%
# PC17: 0.29% | cumulative: 99.36%
# PC18: 0.20% | cumulative: 99.56%
# PC19: 0.14% | cumulative: 99.70%
# PC20: 0.10% | cumulative: 99.80%
# PC21: 0.08% | cumulative: 99.87%
# PC22: 0.05% | cumulative: 99.93%
# PC23: 0.03% | cumulative: 99.96%
# PC24: 0.03% | cumulative: 99.98%
# PC25: 0.01% | cumulative: 100.00%
# PC26: 0.00% | cumulative: 100.00%
# PC27: 0.00% | cumulative: 100.00%
# PC28: 0.00% | cumulative: 100.00%

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=8)

X_pca = pca.fit_transform(X_scaled)

print("X_pca shape:", X_pca.shape)
# Out:
# X_pca shape: (2443, 8)

# %%
explained_variance = pca.explained_variance_ratio_

for i, var in enumerate(explained_variance, start=1):
    print(f"PC{i}: {var:.4f} ({var*100:.2f}%)")

print("Total explained variance:", explained_variance.sum())
# Out:
# PC1: 0.5591 (55.91%)
# PC2: 0.0980 (9.80%)
# PC3: 0.0649 (6.49%)
# PC4: 0.0476 (4.76%)
# PC5: 0.0448 (4.48%)
# PC6: 0.0349 (3.49%)
# PC7: 0.0280 (2.80%)
# PC8: 0.0257 (2.57%)
# Total explained variance: 0.9029948135257039

# %% [markdown]
# ## 6. Final dataframe: windows x PCA

# %%
import pandas as pd

pca_cols = [f"PC{i+1}" for i in range(X_pca.shape[1])]

df_pca = pd.DataFrame(
    X_pca,
    columns=pca_cols,
    index=df_feat_ictalVspreictal_1min.index
)

df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.502730 -0.433297 -0.525056 -0.830375 -0.417839  0.015957 -0.103901
# 1 -1.163551  0.025512 -0.445616  0.611502 -0.624842 -0.226813 -0.133300
# 2 -1.473523 -0.380711 -0.397151  0.159248 -0.426302 -0.419456  0.167533
# 3 -1.589090 -0.297442 -0.408994 -0.487516 -0.518817  0.135907 -0.286677
# 4 -1.601638 -0.359187 -0.505663  0.551114 -0.589387 -0.276385 -0.219402
#
#         PC8
# 0 -0.339337
# 1  0.055804
# 2  0.082602
# 3 -0.532816
# 4 -0.241907

# %% [markdown]
# ## 7. ADD metadata again

# %%
df_windows_pca = pd.concat(
    [
        df_feat_ictalVspreictal_1min[metadata_cols].reset_index(drop=True),
        df_pca.reset_index(drop=True)
    ],
    axis=1
)

df_windows_pca.head()
# Out:
#                     file_name  window_id  start_sample  end_sample  \
# 0  RQXZ1_348_preproc_full.npz        384        794880      796950
# 1  RQXZ1_348_preproc_full.npz        385        796950      799020
# 2  RQXZ1_348_preproc_full.npz        386        799020      801090
# 3  RQXZ1_348_preproc_full.npz        387        801090      803160
# 4  RQXZ1_348_preproc_full.npz        388        803160      805230
#
#            fs  n_channels  window_sec                seizure_onsets  \
# 0  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 1  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 2  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 3  207.031055           2          10  [2021-01-25 22:09:33.000000]
# 4  207.031055           2          10  [2021-01-25 22:09:33.000000]
#
#               window_start_time               window_end_time  ...  \
# 0 2021-01-25 22:03:26.423999874 2021-01-25 22:03:36.422499874  ...
# 1 2021-01-25 22:03:36.422499874 2021-01-25 22:03:46.420999874  ...
# 2 2021-01-25 22:03:46.420999874 2021-01-25 22:03:56.419499873  ...
# 3 2021-01-25 22:03:56.419499873 2021-01-25 22:04:06.417999873  ...
# 4 2021-01-25 22:04:06.417999873 2021-01-25 22:04:16.416499873  ...
#
#    label_name excluded_reason       PC1       PC2       PC3       PC4  \
# 0    preictal            None -1.502730 -0.433297 -0.525056 -0.830375
# 1    preictal            None -1.163551  0.025512 -0.445616  0.611502
# 2    preictal            None -1.473523 -0.380711 -0.397151  0.159248
# 3    preictal            None -1.589090 -0.297442 -0.408994 -0.487516
# 4    preictal            None -1.601638 -0.359187 -0.505663  0.551114
#
#         PC5       PC6       PC7       PC8
# 0 -0.417839  0.015957 -0.103901 -0.339337
# 1 -0.624842 -0.226813 -0.133300  0.055804
# 2 -0.426302 -0.419456  0.167533  0.082602
# 3 -0.518817  0.135907 -0.286677 -0.532816
# 4 -0.589387 -0.276385 -0.219402 -0.241907
#
# [5 rows x 21 columns]

# %%
print(df_windows_pca.shape)
print(df_windows_pca.columns)
# Out:
# (2443, 21)
# Index(['file_name', 'window_id', 'start_sample', 'end_sample', 'fs',
#        'n_channels', 'window_sec', 'seizure_onsets', 'window_start_time',
#        'window_end_time', 'class_label', 'label_name', 'excluded_reason',
#        'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8'],
#       dtype='object')

# %%
# Sanity check:Same number of rows as original df
print(df_feat_ictalVspreictal_1min.shape[0] == df_windows_pca.shape[0])
# Out:
# True

# %% [markdown]
# ## 8. export as pkl

# %%
from pathlib import Path

output_dir = Path("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/RQXZ1/Feature_ext/Part2_features/RQXZ1_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260510_v01_FEAT-TIME-FREQ_20260510_v01/")
output_dir.mkdir(parents=True, exist_ok=True)

output_path = output_dir / "df_windowsRQXZ1_pca.pkl"

df_windows_pca.to_pickle(output_path)

print(f"Saved PCA dataframe to: {output_path}")
print("Shape:", df_windows_pca.shape)
# Out:
# Saved PCA dataframe to: /home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/RQXZ1/Feature_ext/Part2_features/RQXZ1_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260510_v01_FEAT-TIME-FREQ_20260510_v01/df_windowsRQXZ1_pca.pkl
# Shape: (2443, 21)
