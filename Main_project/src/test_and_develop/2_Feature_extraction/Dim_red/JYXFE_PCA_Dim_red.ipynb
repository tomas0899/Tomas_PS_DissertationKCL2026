# %% [markdown]
# # XB47Y: DIM reduction
# gold

# %%
import pandas as pd

df_feat_ictalVspreictal_1min = pd.read_pickle("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/JYXFE/Feature_ext/Part2_features/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260511_v01_FEAT-TIME-FREQ_20260511_v01/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260511_v01_FEAT-TIME-FREQ_20260511_v01_df_features_ictalVspreictal.pkl")

print(df_feat_ictalVspreictal_1min.head())
# Out:
#                    file_name  window_id  start_sample  end_sample          fs  \
# 0  JYXFE_22_preproc_full.npz        983       2034810     2036880  207.031055
# 1  JYXFE_22_preproc_full.npz        984       2036880     2038950  207.031055
# 2  JYXFE_22_preproc_full.npz        985       2038950     2041020  207.031055
# 3  JYXFE_22_preproc_full.npz        986       2041020     2043090  207.031055
# 4  JYXFE_22_preproc_full.npz        987       2043090     2045160  207.031055
#
#    n_channels  window_sec                seizure_onsets  \
# 0           2          10  [2021-05-04 20:33:31.000000]
# 1           2          10  [2021-05-04 20:33:31.000000]
# 2           2          10  [2021-05-04 20:33:31.000000]
# 3           2          10  [2021-05-04 20:33:31.000000]
# 4           2          10  [2021-05-04 20:33:31.000000]
#
#               window_start_time               window_end_time  ...  \
# 0 2021-05-04 20:27:26.525499679 2021-05-04 20:27:36.523999679  ...
# 1 2021-05-04 20:27:36.523999679 2021-05-04 20:27:46.522499678  ...
# 2 2021-05-04 20:27:46.522499678 2021-05-04 20:27:56.520999678  ...
# 3 2021-05-04 20:27:56.520999678 2021-05-04 20:28:06.519499678  ...
# 4 2021-05-04 20:28:06.519499678 2021-05-04 20:28:16.517999678  ...
#
#    alpha_power_EEG_SQ_D_SQ_C beta_power_EEG_SQ_D_SQ_C  \
# 0                   0.041482                 0.088046
# 1                   0.045917                 0.192514
# 2                   0.023462                 0.050349
# 3                   0.021278                 0.052910
# 4                   0.049467                 0.050829
#
#   gamma_power_EEG_SQ_D_SQ_C  peak_frequency_EEG_SQ_D_SQ_C  \
# 0                  0.028388                       1.00015
# 1                  0.137441                       1.00015
# 2                  0.017499                       1.00015
# 3                  0.015703                       1.00015
# 4                  0.015856                       1.00015
#
#    delta_power_EEG_SQ_P_SQ_C  theta_power_EEG_SQ_P_SQ_C  \
# 0                   0.056313                   0.061710
# 1                   0.077294                   0.062397
# 2                   0.050368                   0.040727
# 3                   0.027874                   0.030884
# 4                   0.067611                   0.058001
#
#    alpha_power_EEG_SQ_P_SQ_C  beta_power_EEG_SQ_P_SQ_C  \
# 0                   0.046006                  0.169127
# 1                   0.048663                  0.430183
# 2                   0.011268                  0.023574
# 3                   0.018430                  0.060216
# 4                   0.023925                  0.047306
#
#    gamma_power_EEG_SQ_P_SQ_C  peak_frequency_EEG_SQ_P_SQ_C
# 0                   0.069303                      0.500075
# 1                   0.193675                      1.000150
# 2                   0.007386                      1.500225
# 3                   0.019824                      1.000150
# 4                   0.022754                      1.000150
#
# [5 rows x 41 columns]

# %%
for col in df_feat_ictalVspreictal_1min.columns:
    print(col)
# Out:
# file_name
# window_id
# start_sample
# end_sample
# fs
# n_channels
# window_sec
# seizure_onsets
# window_start_time
# window_end_time
# class_label
# label_name
# excluded_reason
# mean_EEG_SQ_D_SQ_C
# std_EEG_SQ_D_SQ_C
# var_EEG_SQ_D_SQ_C
# rms_EEG_SQ_D_SQ_C
# ptp_EEG_SQ_D_SQ_C
# line_length_EEG_SQ_D_SQ_C
# skew_EEG_SQ_D_SQ_C
# kurtosis_EEG_SQ_D_SQ_C
# mean_EEG_SQ_P_SQ_C
# std_EEG_SQ_P_SQ_C
# var_EEG_SQ_P_SQ_C
# rms_EEG_SQ_P_SQ_C
# ptp_EEG_SQ_P_SQ_C
# line_length_EEG_SQ_P_SQ_C
# skew_EEG_SQ_P_SQ_C
# kurtosis_EEG_SQ_P_SQ_C
# delta_power_EEG_SQ_D_SQ_C
# theta_power_EEG_SQ_D_SQ_C
# alpha_power_EEG_SQ_D_SQ_C
# beta_power_EEG_SQ_D_SQ_C
# gamma_power_EEG_SQ_D_SQ_C
# peak_frequency_EEG_SQ_D_SQ_C
# delta_power_EEG_SQ_P_SQ_C
# theta_power_EEG_SQ_P_SQ_C
# alpha_power_EEG_SQ_P_SQ_C
# beta_power_EEG_SQ_P_SQ_C
# gamma_power_EEG_SQ_P_SQ_C
# peak_frequency_EEG_SQ_P_SQ_C

# %% [markdown]
# ## 1. separate metadata from features

# %%
# Columns that are NOT EEG features
metadata_cols = [
    "file_name",
    "window_id",
    "start_sample",
    "end_sample",
    "fs",
    "n_channels",
    "window_sec",
    "seizure_onsets",
    "window_start_time",
    "window_end_time",
    "class_label",
    "label_name",
    "excluded_reason"
]

# Feature columns = everything except metadata
feature_cols = [col for col in df_feat_ictalVspreictal_1min.columns if col not in metadata_cols]

print("Number of feature columns:", len(feature_cols))
print(feature_cols)
# Out:
# Number of feature columns: 28
# ['mean_EEG_SQ_D_SQ_C', 'std_EEG_SQ_D_SQ_C', 'var_EEG_SQ_D_SQ_C', 'rms_EEG_SQ_D_SQ_C', 'ptp_EEG_SQ_D_SQ_C', 'line_length_EEG_SQ_D_SQ_C', 'skew_EEG_SQ_D_SQ_C', 'kurtosis_EEG_SQ_D_SQ_C', 'mean_EEG_SQ_P_SQ_C', 'std_EEG_SQ_P_SQ_C', 'var_EEG_SQ_P_SQ_C', 'rms_EEG_SQ_P_SQ_C', 'ptp_EEG_SQ_P_SQ_C', 'line_length_EEG_SQ_P_SQ_C', 'skew_EEG_SQ_P_SQ_C', 'kurtosis_EEG_SQ_P_SQ_C', 'delta_power_EEG_SQ_D_SQ_C', 'theta_power_EEG_SQ_D_SQ_C', 'alpha_power_EEG_SQ_D_SQ_C', 'beta_power_EEG_SQ_D_SQ_C', 'gamma_power_EEG_SQ_D_SQ_C', 'peak_frequency_EEG_SQ_D_SQ_C', 'delta_power_EEG_SQ_P_SQ_C', 'theta_power_EEG_SQ_P_SQ_C', 'alpha_power_EEG_SQ_P_SQ_C', 'beta_power_EEG_SQ_P_SQ_C', 'gamma_power_EEG_SQ_P_SQ_C', 'peak_frequency_EEG_SQ_P_SQ_C']

# %% [markdown]
# ## 2. Build matrix

# %%
X = df_feat_ictalVspreictal_1min[feature_cols].copy()
y = df_feat_ictalVspreictal_1min["class_label"].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (322, 28)
# y shape: (322,)

# %% [markdown]
# ## 3. check for NaNs or inf

# %%
import numpy as np

print("NaNs per column:")
print(X.isna().sum())

print("Any infinite values?")
print(np.isinf(X).sum().sum())
# Out:
# NaNs per column:
# mean_EEG_SQ_D_SQ_C              0
# std_EEG_SQ_D_SQ_C               0
# var_EEG_SQ_D_SQ_C               0
# rms_EEG_SQ_D_SQ_C               0
# ptp_EEG_SQ_D_SQ_C               0
# line_length_EEG_SQ_D_SQ_C       0
# skew_EEG_SQ_D_SQ_C              0
# kurtosis_EEG_SQ_D_SQ_C          0
# mean_EEG_SQ_P_SQ_C              0
# std_EEG_SQ_P_SQ_C               0
# var_EEG_SQ_P_SQ_C               0
# rms_EEG_SQ_P_SQ_C               0
# ptp_EEG_SQ_P_SQ_C               0
# line_length_EEG_SQ_P_SQ_C       0
# skew_EEG_SQ_P_SQ_C              0
# kurtosis_EEG_SQ_P_SQ_C          0
# delta_power_EEG_SQ_D_SQ_C       0
# theta_power_EEG_SQ_D_SQ_C       0
# alpha_power_EEG_SQ_D_SQ_C       0
# beta_power_EEG_SQ_D_SQ_C        0
# gamma_power_EEG_SQ_D_SQ_C       0
# peak_frequency_EEG_SQ_D_SQ_C    0
# delta_power_EEG_SQ_P_SQ_C       0
# theta_power_EEG_SQ_P_SQ_C       0
# alpha_power_EEG_SQ_P_SQ_C       0
# beta_power_EEG_SQ_P_SQ_C        0
# gamma_power_EEG_SQ_P_SQ_C       0
# peak_frequency_EEG_SQ_P_SQ_C    0
# dtype: int64
# Any infinite values?
# 0

# %% [markdown]
# ## 4. Scale features before PCA
# PCA needs features to be in comparable scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("X_scaled shape:", X_scaled.shape)
# Out:
# X_scaled shape: (322, 28)

# %% [markdown]
# ## 5. Apply PCA. start with only 5 components first

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA with all possible components
pca_full = PCA()
X_pca_full = pca_full.fit_transform(X_scaled)

# Explained variance
explained_var = pca_full.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

# Print explained variance per PC
for i, (var, cum_var) in enumerate(zip(explained_var, cumulative_var), start=1):
    print(f"PC{i}: {var*100:.2f}% | cumulative: {cum_var*100:.2f}%")
# Out:
# PC1: 64.77% | cumulative: 64.77%
# PC2: 9.71% | cumulative: 74.48%
# PC3: 7.22% | cumulative: 81.71%
# PC4: 5.64% | cumulative: 87.35%
# PC5: 2.90% | cumulative: 90.25%
# PC6: 2.56% | cumulative: 92.81%
# PC7: 2.32% | cumulative: 95.13%
# PC8: 1.49% | cumulative: 96.62%
# PC9: 0.74% | cumulative: 97.35%
# PC10: 0.57% | cumulative: 97.93%
# PC11: 0.38% | cumulative: 98.31%
# PC12: 0.33% | cumulative: 98.64%
# PC13: 0.30% | cumulative: 98.94%
# PC14: 0.25% | cumulative: 99.19%
# PC15: 0.19% | cumulative: 99.38%
# PC16: 0.16% | cumulative: 99.54%
# PC17: 0.12% | cumulative: 99.66%
# PC18: 0.09% | cumulative: 99.75%
# PC19: 0.07% | cumulative: 99.82%
# PC20: 0.06% | cumulative: 99.88%
# PC21: 0.04% | cumulative: 99.93%
# PC22: 0.03% | cumulative: 99.96%
# PC23: 0.02% | cumulative: 99.98%
# PC24: 0.01% | cumulative: 99.99%
# PC25: 0.01% | cumulative: 100.00%
# PC26: 0.00% | cumulative: 100.00%
# PC27: 0.00% | cumulative: 100.00%
# PC28: 0.00% | cumulative: 100.00%

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=8)

X_pca = pca.fit_transform(X_scaled)

print("X_pca shape:", X_pca.shape)
# Out:
# X_pca shape: (322, 8)

# %%
explained_variance = pca.explained_variance_ratio_

for i, var in enumerate(explained_variance, start=1):
    print(f"PC{i}: {var:.4f} ({var*100:.2f}%)")

print("Total explained variance:", explained_variance.sum())
# Out:
# PC1: 0.6477 (64.77%)
# PC2: 0.0971 (9.71%)
# PC3: 0.0722 (7.22%)
# PC4: 0.0564 (5.64%)
# PC5: 0.0290 (2.90%)
# PC6: 0.0256 (2.56%)
# PC7: 0.0232 (2.32%)
# PC8: 0.0149 (1.49%)
# Total explained variance: 0.9661881458298932

# %% [markdown]
# ## 6. Final dataframe: windows x PCA

# %%
import pandas as pd

pca_cols = [f"PC{i+1}" for i in range(X_pca.shape[1])]

df_pca = pd.DataFrame(
    X_pca,
    columns=pca_cols,
    index=df_feat_ictalVspreictal_1min.index
)

df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0 -1.064052  1.294069 -0.460270  0.234506 -1.516932 -0.591967 -0.338460
# 1 -0.073443  0.087551  0.021230 -0.016202  0.061701 -0.904050 -0.185532
# 2 -2.117653 -0.646321 -0.576643 -0.112017  0.019424 -0.528235 -0.108909
# 3 -1.882690  0.041619 -0.415088 -0.582671 -0.208340 -0.325644 -0.157236
# 4 -1.701949 -0.809071 -0.416796 -0.764038  0.032930 -0.341327 -0.049809
#
#         PC8
# 0  0.151425
# 1 -0.525385
# 2  0.264217
# 3 -0.144719
# 4 -0.322452

# %% [markdown]
# ## 7. ADD metadata again

# %%
df_windows_pca = pd.concat(
    [
        df_feat_ictalVspreictal_1min[metadata_cols].reset_index(drop=True),
        df_pca.reset_index(drop=True)
    ],
    axis=1
)

df_windows_pca.head()
# Out:
#                    file_name  window_id  start_sample  end_sample          fs  \
# 0  JYXFE_22_preproc_full.npz        983       2034810     2036880  207.031055
# 1  JYXFE_22_preproc_full.npz        984       2036880     2038950  207.031055
# 2  JYXFE_22_preproc_full.npz        985       2038950     2041020  207.031055
# 3  JYXFE_22_preproc_full.npz        986       2041020     2043090  207.031055
# 4  JYXFE_22_preproc_full.npz        987       2043090     2045160  207.031055
#
#    n_channels  window_sec                seizure_onsets  \
# 0           2          10  [2021-05-04 20:33:31.000000]
# 1           2          10  [2021-05-04 20:33:31.000000]
# 2           2          10  [2021-05-04 20:33:31.000000]
# 3           2          10  [2021-05-04 20:33:31.000000]
# 4           2          10  [2021-05-04 20:33:31.000000]
#
#               window_start_time               window_end_time  ...  \
# 0 2021-05-04 20:27:26.525499679 2021-05-04 20:27:36.523999679  ...
# 1 2021-05-04 20:27:36.523999679 2021-05-04 20:27:46.522499678  ...
# 2 2021-05-04 20:27:46.522499678 2021-05-04 20:27:56.520999678  ...
# 3 2021-05-04 20:27:56.520999678 2021-05-04 20:28:06.519499678  ...
# 4 2021-05-04 20:28:06.519499678 2021-05-04 20:28:16.517999678  ...
#
#    label_name excluded_reason       PC1       PC2       PC3       PC4  \
# 0    preictal            None -1.064052  1.294069 -0.460270  0.234506
# 1    preictal            None -0.073443  0.087551  0.021230 -0.016202
# 2    preictal            None -2.117653 -0.646321 -0.576643 -0.112017
# 3    preictal            None -1.882690  0.041619 -0.415088 -0.582671
# 4    preictal            None -1.701949 -0.809071 -0.416796 -0.764038
#
#         PC5       PC6       PC7       PC8
# 0 -1.516932 -0.591967 -0.338460  0.151425
# 1  0.061701 -0.904050 -0.185532 -0.525385
# 2  0.019424 -0.528235 -0.108909  0.264217
# 3 -0.208340 -0.325644 -0.157236 -0.144719
# 4  0.032930 -0.341327 -0.049809 -0.322452
#
# [5 rows x 21 columns]

# %%
print(df_windows_pca.shape)
print(df_windows_pca.columns)
# Out:
# (322, 21)
# Index(['file_name', 'window_id', 'start_sample', 'end_sample', 'fs',
#        'n_channels', 'window_sec', 'seizure_onsets', 'window_start_time',
#        'window_end_time', 'class_label', 'label_name', 'excluded_reason',
#        'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6', 'PC7', 'PC8'],
#       dtype='object')

# %%
# Sanity check:Same number of rows as original df
print(df_feat_ictalVspreictal_1min.shape[0] == df_windows_pca.shape[0])
# Out:
# True

# %% [markdown]
# ## 8. export as pkl

# %%
from pathlib import Path

output_dir = Path("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/JYXFE/Feature_ext/Part2_features/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260511_v01_FEAT-TIME-FREQ_20260511_v01/")
output_dir.mkdir(parents=True, exist_ok=True)

output_path = output_dir / "df_windows_JYXFEpca.pkl"

df_windows_pca.to_pickle(output_path)

print(f"Saved PCA dataframe to: {output_path}")
print("Shape:", df_windows_pca.shape)
# Out:
# Saved PCA dataframe to: /home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/JYXFE/Feature_ext/Part2_features/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE6to5min_ICT0to1min_GAPasINT_FINAL-PREvsSEIZ_20260511_v01_FEAT-TIME-FREQ_20260511_v01/df_windows_JYXFEpca.pkl
# Shape: (322, 21)
