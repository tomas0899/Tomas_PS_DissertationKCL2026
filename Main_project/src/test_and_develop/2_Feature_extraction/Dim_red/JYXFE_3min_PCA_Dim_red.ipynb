# %% [markdown]
# # JYXFE 3min 19/05/2026: DIM reduction
# gold

# %%
import pandas as pd

df_feat_ictalVspreictal_3min = pd.read_pickle("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/JYXFE/Feature_ext/Part2_features/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE8to5min_ICT0to3min_GAPasINT_FINAL-PREvsSEIZ_20260519_v01_FEAT-TIME-FREQ_20260519_v01/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE8to5min_ICT0to3min_GAPasINT_FINAL-PREvsSEIZ_20260519_v01_FEAT-TIME-FREQ_20260519_v01_df_features_ictalVspreictal.pkl")

print(df_feat_ictalVspreictal_3min.head())
# Out:
#                    file_name  window_id  start_sample  end_sample          fs  \
# 0  JYXFE_22_preproc_full.npz        971       2009970     2012040  207.031055
# 1  JYXFE_22_preproc_full.npz        972       2012040     2014110  207.031055
# 2  JYXFE_22_preproc_full.npz        973       2014110     2016180  207.031055
# 3  JYXFE_22_preproc_full.npz        974       2016180     2018250  207.031055
# 4  JYXFE_22_preproc_full.npz        975       2018250     2020320  207.031055
#
#    n_channels  window_sec                seizure_onsets  \
# 0           2          10  [2021-05-04 20:33:31.000000]
# 1           2          10  [2021-05-04 20:33:31.000000]
# 2           2          10  [2021-05-04 20:33:31.000000]
# 3           2          10  [2021-05-04 20:33:31.000000]
# 4           2          10  [2021-05-04 20:33:31.000000]
#
#               window_start_time               window_end_time  ...  \
# 0 2021-05-04 20:25:26.543499683 2021-05-04 20:25:36.541999683  ...
# ...

# %%
for col in df_feat_ictalVspreictal_3min.columns:
    print(col)
# Out:
# file_name
# window_id
# start_sample
# end_sample
# fs
# n_channels
# window_sec
# seizure_onsets
# window_start_time
# window_end_time
# class_label
# label_name
# excluded_reason
# mean_EEG_SQ_D_SQ_C
# std_EEG_SQ_D_SQ_C
# var_EEG_SQ_D_SQ_C
# rms_EEG_SQ_D_SQ_C
# ptp_EEG_SQ_D_SQ_C
# line_length_EEG_SQ_D_SQ_C
# skew_EEG_SQ_D_SQ_C
# kurtosis_EEG_SQ_D_SQ_C
# mean_EEG_SQ_P_SQ_C
# std_EEG_SQ_P_SQ_C
# var_EEG_SQ_P_SQ_C
# rms_EEG_SQ_P_SQ_C
# ptp_EEG_SQ_P_SQ_C
# line_length_EEG_SQ_P_SQ_C
# skew_EEG_SQ_P_SQ_C
# kurtosis_EEG_SQ_P_SQ_C
# delta_power_EEG_SQ_D_SQ_C
# theta_power_EEG_SQ_D_SQ_C
# alpha_power_EEG_SQ_D_SQ_C
# beta_power_EEG_SQ_D_SQ_C
# gamma_power_EEG_SQ_D_SQ_C
# peak_frequency_EEG_SQ_D_SQ_C
# delta_power_EEG_SQ_P_SQ_C
# theta_power_EEG_SQ_P_SQ_C
# alpha_power_EEG_SQ_P_SQ_C
# beta_power_EEG_SQ_P_SQ_C
# gamma_power_EEG_SQ_P_SQ_C
# peak_frequency_EEG_SQ_P_SQ_C

# %% [markdown]
# ## 1. separate metadata from features

# %%
# Columns that are NOT EEG features
metadata_cols = [
    "file_name",
    "window_id",
    "start_sample",
    "end_sample",
    "fs",
    "n_channels",
    "window_sec",
    "seizure_onsets",
    "window_start_time",
    "window_end_time",
    "class_label",
    "label_name",
    "excluded_reason"
]

# Feature columns = everything except metadata
feature_cols = [col for col in df_feat_ictalVspreictal_3min.columns if col not in metadata_cols]

print("Number of feature columns:", len(feature_cols))
print(feature_cols)
# Out:
# Number of feature columns: 28
# ['mean_EEG_SQ_D_SQ_C', 'std_EEG_SQ_D_SQ_C', 'var_EEG_SQ_D_SQ_C', 'rms_EEG_SQ_D_SQ_C', 'ptp_EEG_SQ_D_SQ_C', 'line_length_EEG_SQ_D_SQ_C', 'skew_EEG_SQ_D_SQ_C', 'kurtosis_EEG_SQ_D_SQ_C', 'mean_EEG_SQ_P_SQ_C', 'std_EEG_SQ_P_SQ_C', 'var_EEG_SQ_P_SQ_C', 'rms_EEG_SQ_P_SQ_C', 'ptp_EEG_SQ_P_SQ_C', 'line_length_EEG_SQ_P_SQ_C', 'skew_EEG_SQ_P_SQ_C', 'kurtosis_EEG_SQ_P_SQ_C', 'delta_power_EEG_SQ_D_SQ_C', 'theta_power_EEG_SQ_D_SQ_C', 'alpha_power_EEG_SQ_D_SQ_C', 'beta_power_EEG_SQ_D_SQ_C', 'gamma_power_EEG_SQ_D_SQ_C', 'peak_frequency_EEG_SQ_D_SQ_C', 'delta_power_EEG_SQ_P_SQ_C', 'theta_power_EEG_SQ_P_SQ_C', 'alpha_power_EEG_SQ_P_SQ_C', 'beta_power_EEG_SQ_P_SQ_C', 'gamma_power_EEG_SQ_P_SQ_C', 'peak_frequency_EEG_SQ_P_SQ_C']

# %% [markdown]
# ## 2. Build matrix

# %%
X = df_feat_ictalVspreictal_3min[feature_cols].copy()
y = df_feat_ictalVspreictal_3min["class_label"].copy()

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (874, 28)
# y shape: (874,)

# %% [markdown]
# ## 3. check for NaNs or inf

# %%
import numpy as np

print("NaNs per column:")
print(X.isna().sum())

print("Any infinite values?")
print(np.isinf(X).sum().sum())
# Out:
# NaNs per column:
# mean_EEG_SQ_D_SQ_C              0
# std_EEG_SQ_D_SQ_C               0
# var_EEG_SQ_D_SQ_C               0
# rms_EEG_SQ_D_SQ_C               0
# ptp_EEG_SQ_D_SQ_C               0
# line_length_EEG_SQ_D_SQ_C       0
# skew_EEG_SQ_D_SQ_C              0
# kurtosis_EEG_SQ_D_SQ_C          0
# mean_EEG_SQ_P_SQ_C              0
# std_EEG_SQ_P_SQ_C               0
# var_EEG_SQ_P_SQ_C               0
# rms_EEG_SQ_P_SQ_C               0
# ptp_EEG_SQ_P_SQ_C               0
# line_length_EEG_SQ_P_SQ_C       0
# skew_EEG_SQ_P_SQ_C              0
# kurtosis_EEG_SQ_P_SQ_C          0
# delta_power_EEG_SQ_D_SQ_C       0
# theta_power_EEG_SQ_D_SQ_C       0
# alpha_power_EEG_SQ_D_SQ_C       0
# beta_power_EEG_SQ_D_SQ_C        0
# gamma_power_EEG_SQ_D_SQ_C       0
# peak_frequency_EEG_SQ_D_SQ_C    0
# delta_power_EEG_SQ_P_SQ_C       0
# theta_power_EEG_SQ_P_SQ_C       0
# alpha_power_EEG_SQ_P_SQ_C       0
# beta_power_EEG_SQ_P_SQ_C        0
# gamma_power_EEG_SQ_P_SQ_C       0
# ...

# %% [markdown]
# ## 4. Scale features before PCA
# PCA needs features to be in comparable scale

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

print("X_scaled shape:", X_scaled.shape)
# Out:
# X_scaled shape: (874, 28)

# %% [markdown]
# ## 5. Apply PCA. start with only 5 components first

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA with all possible components
pca_full = PCA()
X_pca_full = pca_full.fit_transform(X_scaled)

# Explained variance
explained_var = pca_full.explained_variance_ratio_
cumulative_var = np.cumsum(explained_var)

# Print explained variance per PC
for i, (var, cum_var) in enumerate(zip(explained_var, cumulative_var), start=1):
    print(f"PC{i}: {var*100:.2f}% | cumulative: {cum_var*100:.2f}%")
# Out:
# PC1: 63.81% | cumulative: 63.81%
# PC2: 9.74% | cumulative: 73.55%
# PC3: 7.65% | cumulative: 81.20%
# PC4: 5.27% | cumulative: 86.47%
# PC5: 2.65% | cumulative: 89.12%
# PC6: 2.36% | cumulative: 91.48%
# PC7: 2.05% | cumulative: 93.53%
# PC8: 1.65% | cumulative: 95.18%
# PC9: 1.07% | cumulative: 96.25%
# PC10: 0.76% | cumulative: 97.01%
# PC11: 0.63% | cumulative: 97.65%
# PC12: 0.54% | cumulative: 98.18%
# PC13: 0.36% | cumulative: 98.54%
# PC14: 0.32% | cumulative: 98.86%
# PC15: 0.28% | cumulative: 99.14%
# PC16: 0.18% | cumulative: 99.32%
# PC17: 0.17% | cumulative: 99.49%
# PC18: 0.14% | cumulative: 99.63%
# PC19: 0.10% | cumulative: 99.73%
# PC20: 0.09% | cumulative: 99.83%
# PC21: 0.06% | cumulative: 99.88%
# PC22: 0.05% | cumulative: 99.94%
# PC23: 0.03% | cumulative: 99.97%
# PC24: 0.02% | cumulative: 99.99%
# PC25: 0.01% | cumulative: 100.00%
# PC26: 0.00% | cumulative: 100.00%
# PC27: 0.00% | cumulative: 100.00%
# PC28: 0.00% | cumulative: 100.00%

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=6)

X_pca = pca.fit_transform(X_scaled)

print("X_pca shape:", X_pca.shape)
# Out:
# X_pca shape: (874, 6)

# %%
explained_variance = pca.explained_variance_ratio_

for i, var in enumerate(explained_variance, start=1):
    print(f"PC{i}: {var:.4f} ({var*100:.2f}%)")

print("Total explained variance:", explained_variance.sum())
# Out:
# PC1: 0.6381 (63.81%)
# PC2: 0.0974 (9.74%)
# PC3: 0.0765 (7.65%)
# PC4: 0.0527 (5.27%)
# PC5: 0.0265 (2.65%)
# PC6: 0.0236 (2.36%)
# Total explained variance: 0.9147944747103387

# %% [markdown]
# ## 6. Final dataframe: windows x PCA

# %%
import pandas as pd

pca_cols = [f"PC{i+1}" for i in range(X_pca.shape[1])]

df_pca = pd.DataFrame(
    X_pca,
    columns=pca_cols,
    index=df_feat_ictalVspreictal_3min.index
)

df_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6
# 0 -2.091441 -0.926419  0.013863 -0.120551  0.116833  0.396991
# 1 -1.796157 -1.081830 -0.124136  0.532173  0.306827  0.418100
# 2 -1.895183 -0.081375  0.572855 -1.649914 -0.257234  0.784645
# 3 -1.760177 -0.689322  0.019246  0.865503  0.082589  0.626934
# 4 -1.763186 -0.504984 -0.033261  0.321059  0.216742  0.594921

# %% [markdown]
# ## 7. ADD metadata again

# %%
# Keep only metadata columns that actually exist in the dataframe
metadata_cols_available = [
    col for col in metadata_cols 
    if col in df_feat_ictalVspreictal_3min.columns
]

# Optional: show which columns were ignored
metadata_cols_missing = [
    col for col in metadata_cols 
    if col not in df_feat_ictalVspreictal_3min.columns
]

print("Using metadata columns:", metadata_cols_available)
print("Ignored missing columns:", metadata_cols_missing)

# Concatenate available metadata columns with PCA dataframe
df_windows_pca = pd.concat(
    [
        df_feat_ictalVspreictal_3min[metadata_cols_available].reset_index(drop=True),
        df_pca.reset_index(drop=True)
    ],
    axis=1
)

df_windows_pca.head()
# Out:
# Using metadata columns: ['file_name', 'window_id', 'start_sample', 'end_sample', 'fs', 'n_channels', 'window_sec', 'seizure_onsets', 'window_start_time', 'window_end_time', 'class_label', 'label_name', 'excluded_reason']
# Ignored missing columns: []
#                    file_name  window_id  start_sample  end_sample          fs  \
# 0  JYXFE_22_preproc_full.npz        971       2009970     2012040  207.031055
# 1  JYXFE_22_preproc_full.npz        972       2012040     2014110  207.031055
# 2  JYXFE_22_preproc_full.npz        973       2014110     2016180  207.031055
# 3  JYXFE_22_preproc_full.npz        974       2016180     2018250  207.031055
# 4  JYXFE_22_preproc_full.npz        975       2018250     2020320  207.031055
#
#    n_channels  window_sec                seizure_onsets  \
# 0           2          10  [2021-05-04 20:33:31.000000]
# 1           2          10  [2021-05-04 20:33:31.000000]
# 2           2          10  [2021-05-04 20:33:31.000000]
# ...

# %%
print(df_windows_pca.shape)
print(df_windows_pca.columns)
# Out:
# (874, 19)
# Index(['file_name', 'window_id', 'start_sample', 'end_sample', 'fs',
#        'n_channels', 'window_sec', 'seizure_onsets', 'window_start_time',
#        'window_end_time', 'class_label', 'label_name', 'excluded_reason',
#        'PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6'],
#       dtype='object')

# %%
# Sanity check:Same number of rows as original df
print(df_feat_ictalVspreictal_3min.shape[0] == df_windows_pca.shape[0])
# Out:
# True

# %% [markdown]
# ## 8. export as pkl

# %%
from pathlib import Path

output_dir = Path("/home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/JYXFE/Feature_ext/Part2_features/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE8to5min_ICT0to3min_GAPasINT_FINAL-PREvsSEIZ_20260519_v01_FEAT-TIME-FREQ_20260519_v01/")
output_dir.mkdir(parents=True, exist_ok=True)

output_path = output_dir / "df_windows_3minJYXFEpca.pkl"

df_windows_pca.to_pickle(output_path)

print(f"Saved PCA dataframe to: {output_path}")
print("Shape:", df_windows_pca.shape)
# Out:
# Saved PCA dataframe to: /home/tperezsanchez/FoundationModel_EEG_Dissertation/Main_project/results/JYXFE/Feature_ext/Part2_features/JYXFE_IN-normalized_npz_FP-fullnpz_W10s_PRE8to5min_ICT0to3min_GAPasINT_FINAL-PREvsSEIZ_20260519_v01_FEAT-TIME-FREQ_20260519_v01/df_windows_3minJYXFEpca.pkl
# Shape: (874, 19)
